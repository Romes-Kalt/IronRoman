# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw_data.csv", sep=";")

# %%
df
# Out:
#                            id                                   uri  artist  \
# 0      37Nqx7iavZpotJSDXZWbJ3  spotify:track:37Nqx7iavZpotJSDXZWbJ3   Drake
# 1      127QTOFJsJQp5LbJbu3A1y  spotify:track:127QTOFJsJQp5LbJbu3A1y   Drake
# 2      40iJIUlhi6renaREYGeIDS  spotify:track:40iJIUlhi6renaREYGeIDS   Drake
# 3      3dgQqOiQ9fCKVhNOedd2lf  spotify:track:3dgQqOiQ9fCKVhNOedd2lf   Drake
# 4      1zi7xx7UVEFkmKfv06H8x0  spotify:track:1zi7xx7UVEFkmKfv06H8x0   Drake
# ...                       ...                                   ...     ...
# 46768  3i99V5bZNHsWSW3ZtfHCbG  spotify:track:3i99V5bZNHsWSW3ZtfHCbG  Basixx
# 46769  3nEI5HZcf2n0AlHJhhbGir  spotify:track:3nEI5HZcf2n0AlHJhhbGir  Basixx
# 46770  39XxJrw6hA6x2jelt4pRP7  spotify:track:39XxJrw6hA6x2jelt4pRP7  Basixx
# 46771  2SORG76W6KKmpjTdWqGjDc  spotify:track:2SORG76W6KKmpjTdWqGjDc  Basixx
# 46772  2hAkfGJas0noJaFbM3Kps6  spotify:track:2hAkfGJas0noJaFbM3Kps6  Basixx
#
# ...

# %%
df["song"].value_counts()
# Out:
# Y, ¿Si Fuera Ella? - + Es +    62
# Si Supieras                    36
# Báilame - Remix                35
# PORFA - Remix                  30
# Bibi und Tina Lied             23
#                                ..
# Para Tu Amor                    1
# Mala Gente                      1
# La Camisa Negra                 1
# La Flaca (feat. Juanes)         1
# Strange Ways                    1
# Name: song, Length: 31323, dtype: int64

# %%
# df[df["song"] == "Báilame - Remix"]

# %%
df_cleaner = df.drop_duplicates()
df_cleaner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46758 entries, 0 to 46772
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  46758 non-null  object
#  1   uri                 46758 non-null  object
#  2   artist              46758 non-null  object
#  3   song                46758 non-null  object
#  4   danceability        46758 non-null  float64
#  5   energy              46758 non-null  float64
#  6   key                 46758 non-null  int64
#  7   loudness            46758 non-null  float64
#  8   mode                46758 non-null  int64
#  9   speechiness         46758 non-null  float64
#  10  acousticness        46758 non-null  float64
#  11  instrumentalness    46758 non-null  float64
#  12  liveness            46758 non-null  float64
#  13  valence             46758 non-null  float64
#  14  tempo               46758 non-null  float64
# ...

# %%
df_cleaner[df_cleaner["speechiness"] == max(df_cleaner["speechiness"])]
# Out:
#                            id                                   uri  \
# 32396  25dFei0ERKbnvqFF75Opcg  spotify:track:25dFei0ERKbnvqFF75Opcg
#
#           artist                           song  danceability  energy  key  \
# 32396  Lil Dicky  Parental Advisory (Interlude)         0.697   0.266    8
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 32396   -16.846     1        0.961          0.98          0.000005     0.132
#
#        valence    tempo  duration_ms  this_timesignature
# 32396    0.678  137.891        81821                   4
