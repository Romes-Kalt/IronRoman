# %%
import pandas as pd

# %%
df = pd.read_csv("../data/song_db.csv", sep=";", error_bad_lines=False)
# Out:
# b'Skipping line 3335: expected 20 fields, saw 21\nSkipping line 3336: expected 20 fields, saw 21\nSkipping line 3343: expected 20 fields, saw 21\nSkipping line 3345: expected 20 fields, saw 21\nSkipping line 3350: expected 20 fields, saw 21\nSkipping line 4630: expected 20 fields, saw 22\nSkipping line 4632: expected 20 fields, saw 22\nSkipping line 4634: expected 20 fields, saw 22\nSkipping line 4643: expected 20 fields, saw 22\nSkipping line 4644: expected 20 fields, saw 22\nSkipping line 4645: expected 20 fields, saw 22\nSkipping line 4646: expected 20 fields, saw 22\nSkipping line 4647: expected 20 fields, saw 22\nSkipping line 4650: expected 20 fields, saw 22\nSkipping line 4651: expected 20 fields, saw 22\nSkipping line 4655: expected 20 fields, saw 22\nSkipping line 4657: expected 20 fields, saw 22\nSkipping line 4658: expected 20 fields, saw 22\nSkipping line 4659: expected 20 fields, saw 22\nSkipping line 4660: expected 20 fields, saw 22\nSkipping line 4661: expected 20 fiel
# ...

# %%
df
# Out:
#                            id  \
# 0      30QR0ndUdiiMQMA9g1PGCm
# 1      496GZe7MxLloHgUQTmY2Ch
# 2      0kEZlJh4mK1QRfb3CT5LPk
# 3      1hSBVYwG0UPeou0ORftrxm
# 4      5UGAXwbA17bUC0K9uquGY2
# ...                       ...
# 47309  6cGBPNNRb4mt8m3uD9g1w8
# 47310  4zUU0VOduQFLb5iQhmaNDD
# 47311  2H3g6Q8T8g8Dvr0L15ntyv
# 47312  4gxMc88pEX4OnDG1sBW5R3
# 47313  4cDCIRQCWqWI286XMEKvP2
#
#                                                     name  \
# 0      ...And to Those I Love, Thanks for Sticking Ar...
# 1                                     $Outh $Ide $Uicide
# 2                               Kill Yourself (Part III)
# 3                                 Do You Believe in God?
# 4                                             Antarctica
# ...                                                  ...
# 47309                                              Dagon
# 47310                       Chant for Ezkaton 2000 E. V.
# 47311                        Chant for Ezkaton 2000 E.V.
# ...

# %%
df["name"].value_counts()
# Out:
# Jingle Bell Rock               31
# Home                           26
# Bibi und Tina Lied             23
# On & On                        22
# Bad Day                        19
#                                ..
# Pure Love - Single Version      1
# Open The Door To Your Heart     1
# Interlude (Hallelujah)          1
# Keep Love New                   1
# Eskatones                       1
# Name: name, Length: 36159, dtype: int64

# %%
# df[df["song"] == "Báilame - Remix"]

# %%
df_cleaner = df.drop_duplicates()
df_cleaner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45895 entries, 0 to 47313
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                45895 non-null  object
#  1   name              45895 non-null  object
#  2   album             45895 non-null  object
#  3   artist            45895 non-null  object
#  4   release_date      45895 non-null  object
#  5   length            45895 non-null  int64
#  6   popularity        45895 non-null  int64
#  7   danceability      45895 non-null  float64
#  8   acousticness      45895 non-null  float64
#  9   energy            45895 non-null  float64
#  10  instrumentalness  45895 non-null  float64
#  11  liveness          45895 non-null  float64
#  12  loudness          45895 non-null  float64
#  13  speechiness       45895 non-null  float64
#  14  valence           45895 non-null  float64
#  15  key               45895 non-null  int64
# ...

# %%
df_cleaner[df_cleaner["speechiness"] == max(df_cleaner["speechiness"])]
# Out:
#                            id  \
# 494    7n028txCfq4qypWlXB10Hb
# 30211  0PChtYCNpARdIFYpmAaGZ2
#
#                                                     name  \
# 494    Teil 22 - Whisky mit Mord - Abigail Logan ermi...
# 30211  Rapcats (featuring Zaptap/Citizen10) - 087bpm ...
#
#                                                    album          artist  \
# 494    Whisky mit Mord [Abigail Logan ermittelt, Band...  Melinda Mullet
# 30211        Microphonepet (Instrumentals and Acapellas)        Mochipet
#
#       release_date  length  popularity  danceability  acousticness  energy  \
# 494     2020-03-20  183388          20         0.639         0.425   0.243
# 30211   2008-04-22  231724           0         0.646         0.392   0.308
#
#        instrumentalness  liveness  loudness  speechiness  valence  key  mode  \
# 494                 0.0     0.322   -15.619        0.967    0.311    3     1
# 30211               0.0     0.283   -17.206        0.967    0.749   10     0
#
# ...

# %%
smaller_df
# Out:
#                            id  \
# 12431  2VDkMgdj0IoE9I3jo08dlG
# 47261  0tNuJpBgtE65diL6Q8Q7fI
# 47262  6sIMSl1n3KDPr03Fw8mujd
# 47263  2jAn0rAOyLW6hIEuIDNcoT
# 47264  1bSWuHCXabkhubUywqCe47
# 47265  5h5BrNPFvc4IXfCgnZJ2lT
# 47268  3WgutPPpDfVHYgwPGXKFY1
# 47269  74HYrIbnpc2xKCTenv5qKM
# 47271  6s4xndGKUhW0xXPYvFlwcL
# 47272  1MCem6JigI6jgQPMgriKbU
# 47274  1Df4urfsVBB0CGQVBPIFHi
# 47276  0836NZwDmMNJ5upXwt41ji
# 47283  58yWJFglBzvZ7Zao70lGtJ
# 47284  1rqduvolf1CVHSzY519bPp
# 47285  15QJXeFMsil7J8hHWaC8Ma
# 47286  4FiGJgMiDSLJ90exAXnYdz
# 47287  7otmKWoMlpWkrMnnIQHXEg
# 47288  0QQDaKW7eRRoqvbLCylzrn
# 47289  6uI95ERPZV6tivkNWsOKet
# 47290  6zfVYM5Nne0EzpjzYfJKwp
# 47292  3yviy2FnhZkjcoij8LW8tg
# 47294  66q8IX1czlTF7BUYZ7CNts
# 47298  5yVXM9s0oNYIixOLiYI5Nl
# 47299  0yNmRnAp4ypcxObW8dDXHl
# 47300  03ewc1CLMQNnTR0FKXVyAG
# 47301  5X95iShX25IVdya18zunzN
# 47302  2ESN3ebvvqXcFAMxxn6QXF
# 47303  7gFOV5enJuo9tmfV2J2kTh
# 47304  2ilGFcW82jinSytbJIyzCm
# 47305  1FAL6jmxa7oIZxmqZFZZL4
# ...
